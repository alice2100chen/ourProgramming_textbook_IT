# %%
s =[[31,52,32,58,0],[25,38,16,68,0],[53,62,35,77,0],[21,36,24,45,0],[43,45,48,53,0],[23,65,55,32,0]]
for i in range(6):
  for j in range(4):
    s[i][4] = s[i][4] + s[i][j];
  print(s[i][4])
# Out:
# 173
# 147
# 227
# 126
# 189
# 175
