# %%
yourName = input("請輸入你的名字: ")
superstarName = input("請輸入籃球隊員名字: ")
message = input("請輸入想對他說的話: ")

print(superstarName)
print(message)
print("最愛你的粉絲", yourName)
# Out:
# 請輸入你的名字: Hebe
# 請輸入籃球隊員名字: Jay
# 請輸入想對他說的話: 永遠支持你!加油!
# Jay
# 永遠支持你!加油!
# 最愛你的粉絲 Hebe
