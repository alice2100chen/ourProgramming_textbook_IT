# %%
h = 1545
c = 20
s = 12
t = c - (h / 1000) * 6 - (s ** 0.5)
print(t)
# Out:
# 7.265898384862246

# %% [markdown]
# 高山上體感溫度

# %%
def temp(c, h, s):
    t = c - (h / 1000) * 6 - (s ** 0.5)
    return t

x = temp(20,1545, 12)
print(x)
# Out:
# 7.265898384862246
